# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("ml-100k/item_cc_genre.csv")

# %%
df['movie_title']=df['movie_title'].apply(lambda x:x.lower().strip())

# %%
df['director']=df["director"].astype(str)
df['director']=df['director'].apply(lambda x: x.lower().replace(" ",""))

# %%
df['actor1']=df["actor1"].astype(str)
df['actor1']=df['actor1'].apply(lambda x: x.lower().replace(" ",""))
#ensuring Case variasion in the actor's name is not identified as a different actor

# %%
df['actor2']=df["actor2"].astype(str)
df['actor2']=df['actor2'].apply(lambda x: x.lower().replace(" ",""))

# %%
df['director'] = df['director'].apply(lambda x: x+" "+x+" "+x )
#adding weight to director by replicating the direcor name thrice

# %%
df['year']=df['year'].astype(str)

# %%
df['hybrid'] = df['director'] +" "+ df['actor1'] +" "+ df['actor2'] +" "+ df['genre']+" "+df['year']

# %%
df['hybrid']=df['hybrid'].astype(str)

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from ast import literal_eval
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import wordnet

# %%
count = CountVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')

# %%
count_matrix = count.fit_transform(df['hybrid'])

# %%
cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %%
titles = df['movie_title']
indices = pd.Series(df.index, index=df['movie_title'])

# %%
def get_recommendations(title):
    try:
        title=title.lower().strip()
        idx = indices[title]
        print(idx)
        sim_scores = list(enumerate(cosine_sim[idx]))
        sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
        sim_scores = sim_scores[1:31]
        movie_indices = [i[0] for i in sim_scores]
        d=df[df["movie_title"]==title]["director"].to_string().split()[1]
        a1=df[df["movie_title"]==title]["actor1"].to_string().split()[1]
        a2=df[df["movie_title"]==title]["actor2"].to_string().split()[1]
       
        return titles.iloc[movie_indices].head(15),d,a1,a2
    
    except:
        return "movie not in the database"

# %%
get_recommendations("toy story")
# Out:
# 0
# (1217                                       goofy movie, a
#  420                       aladdin and the king of thieves
#  994                                        big green, the
#  94                                                aladdin
#  818                                             space jam
#  991                                              hercules
#  843                                    that thing you do!
#  62                                      santa clause, the
#  1064                                                balto
#  1410    land before time iii: the time of the great gi...
#  7                                                    babe
#  540                                            pocahontas
#  1468                                     gumby: the movie
#  558                         kid in king arthur's court, a
#  25                                 brothers mcmullen, the
#  Name: movie_title, dtype: object, 'johnlasseter', 'tomhanks', 'timallen')

# %%
# Out:
#                                          genre  movie_id  \
# 0                  Animation Children's Comedy         1
# 1                    Action Adventure Thriller         2
# 2                                     Thriller         3
# 3                          Action Comedy Drama         4
# 4                         Crime Drama Thriller         5
# 5                                        Drama         6
# 6                                 Drama Sci-Fi         7
# 7                      Children's Comedy Drama         8
# 8                                        Drama         9
# 9                                    Drama War        10
# 10                              Crime Thriller        11
# 11                              Crime Thriller        12
# 12                                      Comedy        13
# 13                               Drama Romance        14
# 14                                       Drama        15
# 15                              Comedy Romance        16
# 16         Action Comedy Crime Horror Thriller        17
# 17                                       Drama        18
# 18                                       Drama        19
# 19                               Drama Romance        20
# 20    Action Adventure Comedy Musical Thriller        21
# 21                            Action Drama War        22
# 22                              Drama Thriller        23
# 23                      Action Adventure Crime        24
# 24                                      Comedy        25
# 25                                      Comedy        26
# 26                                      Action        27
# 27                       Action Drama Thriller        28
# 28               Action Adventure Comedy Crime        29
# 29                                       Drama        30
# 1677       michaelradford michaelradford michaelradford
# 1678                peterhowitt peterhowitt peterhowitt
# 1679       thomasschlamme thomasschlamme thomasschlamme
# 1680             wernerherzog wernerherzog wernerherzog
#
#                         actor1                actor2  \
# 0                     tomhanks              timallen
# 1                piercebrosnan              seanbean
# 2                      timroth       antoniobanderas
# 3                 johntravolta           genehackman
# 4              sigourneyweaver           hollyhunter
# 5                       gongli            libao-tian
# 6                  brucewillis        madeleinestowe
# 7           christinecavanaugh       miriammargolyes
# 8                susansarandon              seanpenn
# 9                     alpacino           winonaryder
# 10                    bradpitt         morganfreeman
# 11              stephenbaldwin           kevinspacey
# 12                  woodyallen           mirasorvino
# 13              philippenoiret         massimotroisi
# 14             richarddreyfuss          glenneheadly
# 15               victoriaabril        josianebalasko
# 16               georgeclooney      quentintarantino
# 17           aidamohammadkhani          mohsenkafili
# 18         willekevanammelrooy         elsdottermans
# 19                 markrylance    kristinscottthomas
# 20                    timcurry           kevinbishop
# 21                   melgibson    catherinemccormack
# 22                robertdeniro           jodiefoster
# 23                  jackiechan              anitamui
# 24               robinwilliams            nathanlane
# 25                 sharialbert           maxinebahns
# 26                   willsmith        martinlawrence
# 27                    tomhanks            billpaxton
# 28                   valkilmer         tommyleejones
# 29            catherinedeneuve             jeansorel
# ...                        ...                   ...
# 1651                moirakelly           martinsheen
# 1652  scott'carrottop'thompson  courtneythorne-smith
# 1653           harleyjanekozak     elizabethmcgovern
# 1654                jonbonjovi     penelopeannmiller
# 1655                       nan                   nan
# 1656               tonygoldwyn         timothyhutton
# 1657                jacklemmon            danaykroyd
# 1658             iainrobertson        josephmcfadden
# 1659               peterweller             judydavis
# 1660              bridgetfonda          russellcrowe
# 1661                stephenrea          lotteverbeek
# 1662                  joepesci         kristyswanson
# 1663              nickchinlund         michaelraynor
# 1664                 debbyryan          aaronjeffery
# 1665                ricknegron          kristinmoreu
# 1666            illeanadouglas      paulinaporizkova
# 1667              joannamerlin      kathleenchalfant
# 1668              jasonbrouwer             t.j.timon
# 1669                stephenrea        brendangleeson
# 1670            verónicaforqué         victoriaabril
# 1671          edwardjamesolmos             seanyoung
# 1672               annamagnani        ettoregarofolo
# 1673            woodyharrelson            talisasoto
# 1674             emilioestevez            kathybates
# 1675          michaelimperioli           mirasorvino
# 1676                hiamabbass      diamandbouabboud
# 1677               asiaargento           jaredharris
# 1678            gwynethpaltrow            johnhannah
# 1679            martinlawrence                   nan
# 1680          donaldsutherland            braddourif
#
#                                                  hybrid
# 0     johnlasseter johnlasseter johnlasseter tomhank...
# 1     martincampbell martincampbell martincampbell p...
# 2     allisonanders allisonanders allisonanders timr...
# 3     barrysonnenfeld barrysonnenfeld barrysonnenfel...
# 4     jonamiel jonamiel jonamiel sigourneyweaver hol...
# 5     zhangyimou zhangyimou zhangyimou gongli libao-...
# 6     terrygilliam terrygilliam terrygilliam brucewi...
# 7     chrisnoonan chrisnoonan chrisnoonan christinec...
